# %% [markdown]
# Data Ingestion

# %%
#Document structure

from langchain_core.documents import Document

# %%
#creating a sample document
doc = Document(
    page_content="This is a sample document demonstrating the structure of a document in LangChain.",
    metadata={"source": "sample_source",
              "pages": 1,
              "author": "Aditya Pagare",
              "date_created": "2024-06-01"}
)

doc
# Out:
# Document(metadata={'source': 'sample_source', 'pages': 1, 'author': 'Aditya Pagare', 'date_created': '2024-06-01'}, page_content='This is a sample document demonstrating the structure of a document in LangChain.')

# %%
## create a simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
"../data/text_files/python_intro.txt": """ Python Programming Intorduction

Python is a high-level, interpreted programming language known for its simplicity and readability. 
It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. 
Python's extensive standard library and active community make it a popular choice for web development, data analysis, artificial intelligence, scientific computing, and more.

Key Features:
- Easy to Learn and Use: Python's syntax is clear and concise, making it accessible for beginners.
- Versatile: Python can be used for a wide range of applications, from web development to data science and machine learning.
- Extensive Libraries: Python has a rich ecosystem of libraries and frameworks that simplify development tasks.
- Cross-Platform: Python runs on various operating systems, including Windows, macOS, and Linux.""",

"../data/text_files/machine_learning.txt": """ Machine learning Basics

Machine learning is a subset of artificial intelligence that focuses on building systems that can learn from data and improve their performance over time without being explicitly programmed. 
It involves the use of algorithms and statistical models to analyze and interpret complex data patterns.

Key Concepts:
- Supervised Learning: In supervised learning, the model is trained on labeled data, where the input-output pairs are provided. The goal is to learn a mapping from inputs to outputs.
- Unsupervised Learning: In unsupervised learning, the model is trained on unlabeled data, and it aims to find hidden patterns or structures within the data.
- Reinforcement Learning: In reinforcement learning, an agent learns to make decisions by interacting with an environment and receiving feedback in the form of rewards or penalties."""

}


for file_path, content in sample_texts.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=" Python Programming Intorduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt supports multiple programming paradigms, including procedural, object-oriented, and functional programming. \nPython's extensive standard library and active community make it a popular choice for web development, data analysis, artificial intelligence, scientific computing, and more.\n\nKey Features:\n- Easy to Learn and Use: Python's syntax is clear and concise, making it accessible for beginners.\n- Versatile: Python can be used for a wide range of applications, from web development to data science and machine learning.\n- Extensive Libraries: Python has a rich ecosystem of libraries and frameworks that simplify development tasks.\n- Cross-Platform: Python runs on various operating systems, including Windows, macOS, and Linux.")]

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader("../data/text_files", glob="*.txt", loader_cls=TextLoader, loader_kwargs={"encoding": "utf-8"},show_progress=True)
documents = dir_loader.load()
documents
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 829.73it/s]
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader = DirectoryLoader("../data/pdf_files", glob="*.pdf", loader_cls=PyMuPDFLoader,show_progress=True)
pdf_documents = dir_loader.load()
pdf_documents
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
# [Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2026-01-23T11:34:04+05:30', 'source': '..\\data\\pdf_files\\2026 Pinnacle Commissions_TBM AS KAM_GI PRIMA.pdf', 'file_path': '..\\data\\pdf_files\\2026 Pinnacle Commissions_TBM AS KAM_GI PRIMA.pdf', 'total_pages': 27, 'format': 'PDF 1.7', 'title': '2025 Pinnacle Commissions_TBM_v3.0', 'author': 'Monteiro, Francis', 'subject': '2025 Pinnacle Commissions_TBM_v3.0', 'keywords': '2025 Pinnacle Commissions_TBM_v3.0', 'moddate': '2026-01-23T11:34:04+05:30', 'trapped': '', 'modDate': "D:20260123113404+05'30'", 'creationDate': "D:20260123113404+05'30'", 'page': 0}, page_content='Proprietary and confidential — do not distribute\nPINNACLE 2026\nCOMMISSIONS│REWARDS│RECOGNITION\nABBOTT INDIA\n2 0 2 6\nTBM,AS,KAM\nGI PRIMA'),
# ...

# %% [markdown]
# Chunking
